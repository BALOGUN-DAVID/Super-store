# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
super_store= pd.read_excel("KMS Superstore Data_Balogun David Taiwo (Autosaved).xlsx")
super_store
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
super_store.isna().sum()
# Out:
# Row ID                   0
# Order ID                 0
# Order Date               0
# Order Priority           0
# Order Quantity           0
# Sales                    0
# Discount                 0
# Ship Mode                0
# Profit                   0
# Unit Price               0
# Shipping Cost            0
# Customer Name            0
# Province                 0
# Region                   0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Name             0
# Product Container        0
# Product Base Margin     63
# Ship Date                0
# dtype: int64

# %%
super_store["Product Base Margin"].isna().sum()
# Out:
# 63

# %%
new_super_store = super_store.dropna()
new_super_store
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
new_super_store.isna().sum()
# Out:
# Row ID                  0
# Order ID                0
# Order Date              0
# Order Priority          0
# Order Quantity          0
# Sales                   0
# Discount                0
# Ship Mode               0
# Profit                  0
# Unit Price              0
# Shipping Cost           0
# Customer Name           0
# Province                0
# Region                  0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Name            0
# Product Container       0
# Product Base Margin     0
# Ship Date               0
# dtype: int64

# %%
new_super_store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
new_super_store.shape
# Out:
# (8336, 21)

# %%
new_super_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8336 entries, 0 to 8398
# Data columns (total 21 columns):
# Row ID                  8336 non-null int64
# Order ID                8336 non-null int64
# Order Date              8336 non-null datetime64[ns]
# Order Priority          8336 non-null object
# Order Quantity          8336 non-null int64
# Sales                   8336 non-null float64
# Discount                8336 non-null float64
# Ship Mode               8336 non-null object
# Profit                  8336 non-null float64
# Unit Price              8336 non-null float64
# Shipping Cost           8336 non-null float64
# Customer Name           8336 non-null object
# Province                8336 non-null object
# Region                  8336 non-null object
# Customer Segment        8336 non-null object
# Product Category        8336 non-null object
# Product Sub-Category    8336 non-null object
# Product Name            8336 non-null object
# ...

# %%
new_super_store.describe()
# Out:
#             Row ID      Order ID  Order Quantity         Sales     Discount  \
# count  8336.000000   8336.000000     8336.000000   8336.000000  8336.000000
# mean   4201.256238  29974.350408       25.573896   1757.100276     0.049616
# std    2424.179426  17256.903785       14.494657   3576.433039     0.031809
# min       1.000000      3.000000        1.000000      2.240000     0.000000
# 25%    2102.750000  15033.750000       13.000000    141.971625     0.020000
# 50%    4200.500000  29858.500000       26.000000    442.740000     0.050000
# 75%    6301.250000  44609.250000       38.000000   1678.515000     0.080000
# max    8399.000000  59973.000000       50.000000  89061.050000     0.250000
#
#              Profit   Unit Price  Shipping Cost  Product Base Margin
# count   8336.000000  8336.000000    8336.000000          8336.000000
# mean     178.411589    88.716087      12.717320             0.512513
# std     1192.010697   291.195650      17.200793             0.135589
# ...

# %%
new_super_store
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %% [raw]
# PRODUCT CATEGORY BY SALES

# %%
product_category = new_super_store.groupby("Product Category").agg({"Sales":'sum'})
product_category
# Out:
#                         Sales
# Product Category
# Furniture         4952119.462
# Office Supplies   3710820.260
# Technology        5984248.182

# %%
plt.figure(figsize=(8,8))
plt.pie(x=[379,270,176],labels = ["Furniture","Office Supplies","Technology"], autopct = "2.of%%", colors=['g','b','r'], labeldistance =0.9, pctdistance = 0.9, data = new_super_store)
# Out:
# ([<matplotlib.patches.Wedge at 0x16b3339f548>,
# ...
#  [Text(0.11449976347316106, 0.8926868455200794, 'Furniture'),
#   Text(-0.6442231782769542, -0.6284715558963188, 'Office Supplies'),
#   Text(0.7053241025209114, -0.5590330136969291, 'Technology')],
#  [Text(0.11449976347316106, 0.8926868455200794, '2.of%'),
#   Text(-0.6442231782769542, -0.6284715558963188, '2.of%'),
#   Text(0.7053241025209114, -0.5590330136969291, '2.of%')])

# %%
#Region analysis by sales

# %%
new_super_store["Region"].unique()
# Out:
# array(['Nunavut', 'Northwest Territories', 'Atlantic', 'Prarie', 'West',
#        'Ontario', 'Quebec', 'Yukon'], dtype=object)

# %%
region_sale = new_super_store.groupby("Region").agg({"Sales":'sum'})
region_sale
# Out:
#                               Sales
# Region
# Atlantic               1.975004e+06
# Northwest Territories  7.667522e+05
# Nunavut                1.062934e+05
# Ontario                3.019145e+06
# Prarie                 2.773572e+06
# Quebec                 1.487015e+06
# West                   3.547958e+06
# Yukon                  9.714487e+05

# %%
sns.boxplot(x = "Region", y = "Sales",color = "blue", data =new_super_store)
plt.xticks(rotation = "vertical" , size = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
new_super_store
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1         49       293 2012-10-01           High              49  10123.0200
# 2         50       293 2012-10-01           High              27    244.5700
# 3         80       483 2011-07-10           High              30   4965.7595
# 4         85       515 2010-08-28  Not Specified              19    394.2700
# ...      ...       ...        ...            ...             ...         ...
# 8394    7765     55558 2010-08-09         Medium               8   1294.0400
# 8395    7766     55558 2010-08-09         Medium              23    392.5700
# 8396    7906     56550 2011-04-08  Not Specified              37    823.7800
# 8397    7907     56550 2011-04-08  Not Specified               8    469.8375
# 8398    7914     56581 2009-02-08           High              20   2026.0100
#
# ...

# %%
#customer with their purchase order
purchase_order = new_super_store.groupby("Customer Name").agg({"Order Quantity":'sum'})
purchase_order_sequence = purchase_order.sort_values("Order Quantity")
purchase_order_sequence
# Out:
#                    Order Quantity
# Customer Name
# Craig Carreira                  8
# Tiffany House                  17
# Anthony Jacobs                 19
# Natalie DeCherney              21
# Anne McFarland                 27
# ...                           ...
# Quincy Jones                  864
# Brad Thomas                   868
# Carlos Soltero                896
# Ed Braxton                   1016
# Darren Budd                  1105
#
# [795 rows x 1 columns]

# %%
purchase_order_sequence.tail().plot()

# %%
purchase_order_sequence.tail().sns

# %%
Top_5_highest_purchase = purchase_order_sequence.tail()
Top_5_highest_purchase
# Out:
#                 Order Quantity
# Customer Name
# Quincy Jones               864
# Brad Thomas                868
# Carlos Soltero             896
# Ed Braxton                1016
# Darren Budd               1105

# %%
new_super_store.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3 2010-10-13            Low               6    261.5400
# 1      49       293 2012-10-01           High              49  10123.0200
# 2      50       293 2012-10-01           High              27    244.5700
# 3      80       483 2011-07-10           High              30   4965.7595
# 4      85       515 2010-08-28  Not Specified              19    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sns.violinplot(x = "Customer Segment", y ="Profit", data =new_super_store, gridsize=100)

# %%
#Profit made by each shipping mode 
sns.barplot(x = "Ship Mode", y= "Profit", data = new_super_store ,palette = "rainbow")

# %%
#product category by order quantitty
sns.catplot(x ="Product Category", y = "Order Quantity", data = new_super_store, legend=True)
